# %%
# Patricia Hurlocker
# MatPlotLib Homework #2 pyPharma
# 0. Use matplotlib
# %matplotlib inline

# %%
# 1. Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2. File Paths
file_1 = "data/clinicaltrial_data.csv"
file_2 = "data/mouse_drug_data.csv"

# %%
# 3. Read the csv data files 
clinical_trial_data = pd.read_csv(file_1)
mouse_drug_data = pd.read_csv(file_2)

# %%
# 4. Merge files together into one DataFrame and Display the Output
merged_file = pd.merge(clinical_trial_data, mouse_drug_data, left_index=True, on="Mouse ID")
# 5. Display output
merged_file.head()
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 75     b128          0           45.000000                 0  Capomulin
# 75     b128          5           45.651331                 0  Capomulin
# 75     b128         10           43.270852                 0  Capomulin
# 75     b128         15           43.784893                 0  Capomulin
# 75     b128         20           42.731552                 0  Capomulin

# %%
# 6. Calculate average tumor volume change over time for each drug and display the dataframe 
avg_volume = pd.DataFrame(merged_file.groupby(["Drug","Timepoint"])["Tumor Volume (mm3)"].mean())
avg_volume.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325

# %%
# 7. Calculate sem for average tumor volume change over time for each drug and display dataframe head
volume_sem = pd.DataFrame(merged_file.groupby(["Drug","Timepoint"])["Tumor Volume (mm3)"].sem())
volume_sem.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                    0.000000
#           5                    0.448593
#           10                   0.702684
#           15                   0.838617
#           20                   0.909731

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# 8. Reformat DataFrame: set name of drugs as columns
avg_volume = avg_volume.unstack(level = 0)

# 9. Set column as only drug names
avg_volume.columns = avg_volume.columns.get_level_values(1)

# 10. Display the dataframe head
avg_volume.head()
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# 11.  Do the work to setup the chart and graph the results

# Create an index for the x-axis data
x_axis = avg_volume.index

# Set size of scatter plots
plt.figure(figsize=(9,5))

# Create scatter plot for tumor response to "Capomulin"
plt.errorbar(x_axis, avg_volume["Capomulin"],yerr=avg_volume["Capomulin"].sem(), 
             marker ="o", linestyle= "--", label="Capomulin")
# Create scatter plot for tumor response to "Infubinol"
plt.errorbar(x_axis, avg_volume["Infubinol"],yerr=avg_volume["Infubinol"].sem(), 
             marker ="^", linestyle= "--", label="Infubinol")
# Create scatter plot for tumor response to "Ketapril"
plt.errorbar(x_axis, avg_volume["Ketapril"],yerr=avg_volume["Ketapril"].sem(), 
             marker ="*", linestyle= "--", label="Ketapril")
# Create scatter plot for tumor response to "Placebo"
plt.errorbar(x_axis, avg_volume["Placebo"],yerr=avg_volume["Placebo"].sem(), 
             marker ="s", linestyle= "--", label="Placebo")

# Chart Aesthetics 
plt.title("Tumor Response to Treatment", fontsize=14)
plt.xlabel("Time (Days)", fontsize=10)
plt.ylabel("Tumor Volume (mm3)", fontsize=10)
plt.xticks(np.arange(0, avg_volume.index.max()+5, 5))
plt.yticks(np.arange(20, 90, 10))

# Create a legend
legend = plt.legend(numpoints= 1, 
                    markerscale= 1, 
                    fontsize= 10, 
                    frameon=True, 
                    edgecolor="black")

# Add a grid and show the chart
plt.grid()

# 12.  Save the chart to a file
plt.savefig("charts/Scatter_plt_Tumor_Response_2_drugs_with_labels.png")

# %%
# Show the chart
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# 13. Calcualate the mean of the Metastatic Sites groupBy by Drug and Timepoint and display the dataframe head
avg_spread = pd.DataFrame(merged_file.groupby(["Drug","Timepoint"])["Metastatic Sites"].mean())
avg_spread.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# 14. Calculate sem for average metastatic response over time for each drug and display the dataframe head
spread_sem = pd.DataFrame(merged_file.groupby(["Drug","Timepoint"])["Metastatic Sites"].sem())
spread_sem.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# 15. Reformat DataFrame: set name of drugs as columns
avg_spread = avg_spread.unstack(level = 0)

# Set column as drug names
avg_spread.columns = avg_spread.columns.get_level_values(1)

# Display DataFrame
avg_spread.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.320000  0.120000  0.240000   0.166667
# 10         0.565217  0.250000  0.478261   0.500000
# 15         0.764706  0.333333  0.782609   0.809524
# 20         1.000000  0.347826  0.952381   1.294118

# %%
# 16. Create the plot for Tumor Response to treatment
# Set range of x-axis
x_axis = avg_spread.index

# Set size of scatter plots
plt.figure(figsize=(9,5))

# Create scatter plot for metastatic response to "Capomulin"
plt.errorbar(x_axis, avg_spread["Capomulin"],yerr=avg_spread["Capomulin"].sem(), 
             marker ="o", linestyle= "--", label="Capomulin")
# Create scatter plot for metastatic response to "Infubinol"
plt.errorbar(x_axis, avg_spread["Infubinol"],yerr=avg_spread["Infubinol"].sem(), 
             marker ="^", linestyle= "--", label="Infubinol")
# Create scatter plot for metastatic response to "Ketapril"
plt.errorbar(x_axis, avg_spread["Ketapril"],yerr=avg_spread["Ketapril"].sem(), 
             marker ="*", linestyle= "--", label="Ketapril")
# Create scatter plot for metastatic response to "Placebo"
plt.errorbar(x_axis, avg_spread["Placebo"],yerr=avg_spread["Placebo"].sem(), 
             marker ="s", linestyle= "--", label="Placebo")

# Aesthetics 
plt.title("Metastatic Spread During Treatment", fontsize=14)
plt.xlabel("Treatment Duration (Days)", fontsize=10)
plt.ylabel("Met. Sites", fontsize=10)
plt.xticks(np.arange(0, avg_spread.index.max()+5, 5))
plt.yticks(np.arange(0, 4.5, .5))

# Add a legend to to scatter plot
legend = plt.legend(numpoints= 1, 
                    markerscale= 1, 
                    fontsize= 10, 
                    frameon=True, 
                    edgecolor="black")

# Add a grid and display
plt.grid()

#Save the chart to a file
plt.savefig("charts/Scatter_plt_metastatic_spread_during_treatment_with_labels.png")

plt.show()

# %% [markdown]
# ## Survival Rates

# %%
# 17. Calculate number of mice alive over time for each drug
mice_lives = pd.DataFrame(merged_file.groupby(["Drug","Timepoint"])["Mouse ID"].count())

# Display DataFrame
mice_lives.head()
# Out:
#                      Mouse ID
# Drug      Timepoint
# Capomulin 0                25
#           5                25
#           10               25
#           15               24
#           20               23

# %%
# 18. Reformat DataFrame: set name of drugs as columns
mice_lives = mice_lives.unstack(level = 0)

# Set column as only drug names
mice_lives.columns = mice_lives.columns.get_level_values(1)

# Display DataFrame
mice_lives.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# 19. Calculate the Surviaval rate percentage:
survival_percentage = mice_lives.copy()
survival_percentage = round(survival_percentage.apply(lambda c: c / c.max()) * 100)

# %% [markdown]
# ## Summary Bar Graph

# %%
# 20. Set range of x-axis
x_axis = survival_percentage.index

#Set size of scatter plots
plt.figure(figsize=(9,5))

#Create scatter plot for percentage of survival rate for mice on "Capomulin"
plt.errorbar(x_axis, survival_percentage["Capomulin"], marker ="o", linestyle= "--", label="Capomulin")
#Create scatter plot for percentage of survival rate for mice on "Infubinol"
plt.errorbar(x_axis, survival_percentage["Infubinol"], marker ="^", linestyle= "--", label="Infubinol")
#Create scatter plot for percentage of survival rate for mice on "Ketapril"
plt.errorbar(x_axis, survival_percentage["Ketapril"], marker ="*", linestyle= "--", label="Ketapril")
#Create scatter plot for percentage of survival rate for mice on "Placebo"
plt.errorbar(x_axis, survival_percentage["Placebo"], marker ="s", linestyle= "--", label="Placebo")

#Aesthetics 
plt.title("Survival During Treatment", fontsize=14)
plt.xlabel("Time (Days)", fontsize=10)
plt.ylabel("Survival Rate (%)", fontsize=10)
plt.xticks(np.arange(0, 50, 5))
plt.yticks(np.arange(40, 110, 10))

#Add legend
legend = plt.legend(loc = "lower left", 
                    numpoints= 1, 
                    markerscale= 1, 
                    fontsize= 10, 
                    frameon=True, 
                    edgecolor="black")

plt.grid()
#Save the chart to a file
plt.savefig("charts/Scatter_plt_survival_during_treatment_with_labels.png")
plt.show()

# %%
# 21. Determine the tumor growth change
total_tumor_growth = (((avg_volume.iloc[-1] - avg_volume.iloc[0]) / avg_volume.iloc[0]) * 100).to_frame("% Change")
total_tumor_growth
# Out:
#             % Change
# Drug
# Capomulin -19.475303
# Ceftamin   42.516492
# Infubinol  46.123472
# Ketapril   57.028795
# Naftisol   53.923347
# Placebo    51.297960
# Propriva   47.241175
# Ramicane  -22.320900
# Stelasyn   52.085134
# Zoniferol  46.579751

# %%
# 22. Set range of x-axis
x_axis = total_tumor_growth.index
y_axis = total_tumor_growth["% Change"]

#Set size of scatter plots
plt.figure(figsize=(9,5))

#Conditional formating for aesthetics 
colors = ["red" if _y >= 0 else "green" for _y in y_axis ]


sns.barplot(x_axis, y_axis, palette=colors)

#Save the chart to a file
plt.savefig("charts/BarChart_plt_pct_change_with_labels.png")

plt.show()

# %%
# 23. Using the values from the % total change for the specified drugs
all_data = {'treatment': ['Capomulin', 'Ketapril', 'Infubino', 'Placebo'],
           'Total % Change': [-19.475303 , 46.123472, 57.028795, 51.297960]}
bar_data_df = pd.DataFrame(all_data)

#all_data = {'treatment': ['Capomulin', 'Ketapril', 'Infubino', 'Placebo'],
#             'Total % Change': [C_Vol_Change_df , I_Vol_Change_df,K_Vol_Change_df, P_Vol_Change_df]}
#bar_data_df = pd.DataFrame(all_data)
#bar_data_df.head()

# %%
# 24. Create the chart from the data showing the % change over the 45 day treatment.

ticks = np.arange(6)
barwidth = .5

plt.grid()
plt.rc('axes', axisbelow=True)

plt.bar(ticks[0], -19.475303, width = barwidth, color = 'green', label='Capumolin')
c = np.float(-19.475303)
c = "{:0.3}%".format(c)
plt.text(ticks[0], -19.475303, str(c), horizontalalignment='center', verticalalignment = 'top')

plt.bar(ticks[1], 46.123472, width = barwidth, color = 'red', label='Infubino')
i = np.float(46.123472)
i = "{:0.3}%".format(i)
plt.text(ticks[1], 46.123472, str(i), horizontalalignment='center', verticalalignment = 'bottom')

plt.bar(ticks[2], 57.028795, width = barwidth, color = 'red', label='Ketapril')
k = np.float(57.028795)
k = "{:0.3}%".format(k)
plt.text(ticks[2], 57.028795, str(k), horizontalalignment='center', verticalalignment = 'bottom')

plt.bar(ticks[3], 51.297960, width = barwidth, color = 'red', label='Placebo')
p = np.float(51.297960)
p = "{:0.3}%".format(p)
plt.text(ticks[3], 51.297960, str(p), horizontalalignment='center', verticalalignment = 'bottom')

plt.legend(loc='lower right')
plt.xticks(ticks, bar_data_df['treatment'], rotation=0)
plt.title("Tumor Change Over 45 Day Treatment")
plt.xlabel("Drugs")
plt.ylabel("% Tumor Volume Change")

#Save the chart to a file
plt.savefig("charts/BarChart_tumor_change_45d_treatment_with_labels.png")

plt.show()
